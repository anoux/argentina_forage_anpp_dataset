# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

# %%
df = pd.read_csv(r"C:\Users\Anoux\Desktop\argentina_forage_anpp_dataset\anpp_dataset.csv")

# %%
df
# Out:
#       ID Registro  ID fuente     LAT        LON  Celda  \
# 0             987      10110 -29.725 -65.425000  16785
# 1            4351      10508 -27.650 -58.766667  29049
# 2            4352      10508 -27.650 -58.766667  29049
# 3            4353      10508 -27.650 -58.766667  29049
# 4            4354      10508 -27.650 -58.766667  29049
# ...           ...        ...     ...        ...    ...
# 6377         1118      10137 -28.050 -64.250000  18635
# 6378         1120      10137 -28.050 -64.250000  18635
# 6379         1122      10137 -28.050 -64.250000  18635
# 6380         1124      10137 -28.050 -64.250000  18635
# 6381         1965      10213 -27.500 -59.166667  28304
#
#      Departamento, partido o comuna            Provincia Espontánea Recurso 1  \
# 0               Departamento La Paz            CATAMARCA         Sí    Estepa
# 1              Departamento Capital           CORRIENTES         No   Pastura
# 2              Departamento Capital           CORRIENTES         No   Pastura
# 3              Departamento Capital           CORRIENTES         No   Pastura
# 4              Departamento Capital           CORRIENTES         No   Pastura
# ...                             ...                  ...        ...       ...
# 6377           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6378           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6379           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6380           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6381      Departamento San Fernando                CHACO         No   Pastura
#
#      Recurso 2  ... Precipitación media anual tomada de geoportal IDESA  \
# 0     Pastizal  ...                                                323
# 1      Pastura  ...                                               1340
# 2      Pastura  ...                                               1340
# 3      Pastura  ...                                               1340
# 4      Pastura  ...                                               1340
# ...        ...  ...                                                ...
# 6377  Pastizal  ...                                                505
# 6378  Pastizal  ...                                                505
# 6379  Pastizal  ...                                                505
# 6380  Pastizal  ...                                                505
# 6381   Pastura  ...                                               1310
#
#      Taxonomía de suelo                            Metodología/Comentarios  \
# 0                   NaN  Cortes de brotes nuevos de arbustos forrajeros...
# 1       Argiudol acuico  Tres cortes en total. Altura remanente: 25% de...
# 2       Argiudol acuico  Tres cortes en total. Altura remanente: 50% de...
# 3       Argiudol acuico  Tres cortes en total. Altura remanente: 25% de...
# 4       Argiudol acuico  Tres cortes en total. Altura remanente: 50% de...
# ...                 ...                                                ...
# 6377                NaN  Media loma - buena - rolado seguido de fuego p...
# 6378                NaN  Media loma - buena - rolado solo campo natural...
# 6379                NaN  Media loma, testigo, bosque abierto con fachin...
# 6380                NaN  Media loma, testigo, bosque abierto con fachin...
# 6381  Psamacualf típico                                 fuente desconocida
#
#            REGION   DOMINIO              UNIDAD FITOGEOGRÁFICA  \
# 0     Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 1     Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 2     Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 3     Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 4     Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# ...           ...       ...                                ...
# 6377  Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 6378  Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 6379  Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 6380  Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
# 6381  Neotropical  Chaqueno  Provincia Fitogeografica Chaquena
#
#       Código de Unidad de Vegetación  \
# 0                                  9
# 1                                 15
# 2                                 15
# 3                                 15
# 4                                 15
# ...                              ...
# 6377                              12
# 6378                              12
# 6379                              12
# 6380                              12
# 6381                              15
#
#              Nombre fisionómico de Unidad de Vegetación  \
# 0     Bosque de xerofitas con Aspidosperma quebracho...
# 1     Mosaico de Bosque de xerofitas, de mesofitas, ...
# 2     Mosaico de Bosque de xerofitas, de mesofitas, ...
# 3     Mosaico de Bosque de xerofitas, de mesofitas, ...
# 4     Mosaico de Bosque de xerofitas, de mesofitas, ...
# ...                                                 ...
# 6377       Bosque de xerofitas con Schinopsis lorentzii
# 6378       Bosque de xerofitas con Schinopsis lorentzii
# 6379       Bosque de xerofitas con Schinopsis lorentzii
# 6380       Bosque de xerofitas con Schinopsis lorentzii
# 6381  Mosaico de Bosque de xerofitas, de mesofitas, ...
#
#       Nombre vulgar de Unidad de Vegetación Excluidos del análisis
# 0                               Chaco Arido                    NaN
# 1        Chaco Humedo con Bosques y Canadas                    NaN
# 2        Chaco Humedo con Bosques y Canadas                    NaN
# 3        Chaco Humedo con Bosques y Canadas                    NaN
# 4        Chaco Humedo con Bosques y Canadas                    NaN
# ...                                     ...                    ...
# 6377                        Chaco Semiarido                    NaN
# 6378                        Chaco Semiarido                    NaN
# 6379                        Chaco Semiarido                    NaN
# 6380                        Chaco Semiarido                    NaN
# 6381     Chaco Humedo con Bosques y Canadas                    NaN
#
# [6382 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6382 entries, 0 to 6381
# Data columns (total 48 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   ID Registro                                                            6382 non-null   int64
#  1   ID fuente                                                              6382 non-null   int64
#  2   LAT                                                                    6382 non-null   float64
#  3   LON                                                                    6382 non-null   float64
#  4   Celda                                                                  6382 non-null   int64
#  5   Departamento, partido o comuna                                         6382 non-null   object
#  6   Provincia                                                              6382 non-null   object
#  7   Espontánea                                                             6382 non-null   object
#  8   Recurso 1                                                              6382 non-null   object
#  9   Recurso 2                                                              6382 non-null   object
#  10  Fuente de variación                                                    6382 non-null   object
#  11  Sitioy/o condición                                                     1857 non-null   object
#  12  Composición florística                                                 6382 non-null   object
#  13  Composición florística simplificada (solo vegetación cultivada)        6382 non-null   object
#  14  Riqueza especies                                                       6382 non-null   object
#  15  PPNA (kg/ha.año)                                                       6382 non-null   float64
#  16  DesvEst interanual (n)                                                 69 non-null     float64
#  17  DesvEst interanual (kg/ha)                                             261 non-null    float64
#  18  DesvEst espacial (kg/ha)                                               86 non-null     float64
#  19  Período evaluado (años)                                                6382 non-null   object
#  20  Inicio                                                                 6382 non-null   object
#  21  Final                                                                  6382 non-null   object
#  22  Cantidad de años evaluados                                             6377 non-null   object
#  23  Edad (años)                                                            6382 non-null   object
#  24  Fertilización                                                          6382 non-null   object
#  25  Tratamiento                                                            6382 non-null   object
#  26  Fertilización (N) (kg/ha.año)                                          6382 non-null   object
#  27  Fertilización  (P) (kg/ha.año)                                         6382 non-null   object
#  28  Fertilización  (S) (kg/ha.año)                                         6382 non-null   object
#  29  Fertilización  (K) (kg/ha.año)                                         6382 non-null   object
#  30  Pastoreo                                                               6379 non-null   object
#  31  Clausura                                                               6379 non-null   object
#  32  Riego                                                                  6382 non-null   object
#  33  Cantidad riego (mm)                                                    6379 non-null   object
#  34  Precipitación (mm)                                                     1462 non-null   object
#  35  Precipitación durante el año de medición (mm/estación de crecimiento)  144 non-null    float64
#  36  Precipitación promedio mencionada en la fuente (mm)                    1322 non-null   float64
#  37  Precip. anual promedio según SMN interpolado (mm/año)                  311 non-null    float64
#  38  Precipitación media anual tomada de geoportal IDESA                    6382 non-null   int64
#  39  Taxonomía de suelo                                                     2526 non-null   object
#  40  Metodología/Comentarios                                                4981 non-null   object
#  41  REGION                                                                 6382 non-null   object
#  42  DOMINIO                                                                6382 non-null   object
#  43  UNIDAD FITOGEOGRÁFICA                                                  6382 non-null   object
#  44  Código de Unidad de Vegetación                                         6382 non-null   int64
#  45  Nombre fisionómico de Unidad de Vegetación                             6382 non-null   object
#  46  Nombre vulgar de Unidad de Vegetación                                  6382 non-null   object
#  47  Excluidos del análisis                                                 1431 non-null   object
# dtypes: float64(9), int64(5), object(34)
# memory usage: 2.3+ MB

# %%
list(df.columns.values)
# Out:
# ['ID Registro',
#  'ID fuente',
#  'LAT',
#  'LON',
#  'Celda',
#  'Departamento, partido o comuna',
#  'Provincia',
#  'Espontánea',
#  'Recurso 1',
#  'Recurso 2',
#  'Fuente de variación',
#  'Sitioy/o condición',
#  'Composición florística',
#  'Composición florística simplificada (solo vegetación cultivada)',
#  'Riqueza especies',
#  'PPNA (kg/ha.año)',
#  'DesvEst interanual (n)',
#  'DesvEst interanual (kg/ha)',
#  'DesvEst espacial (kg/ha)',
#  'Período evaluado (años)',
#  'Inicio',
#  'Final',
#  'Cantidad de años evaluados',
#  'Edad (años)',
#  'Fertilización',
#  'Tratamiento',
#  'Fertilización (N) (kg/ha.año)',
#  'Fertilización  (P) (kg/ha.año)',
#  'Fertilización  (S) (kg/ha.año)',
#  'Fertilización  (K) (kg/ha.año)',
#  'Pastoreo',
#  'Clausura',
#  'Riego',
#  'Cantidad riego (mm)',
#  'Precipitación (mm)',
#  'Precipitación durante el año de medición (mm/estación de crecimiento)',
#  'Precipitación promedio mencionada en la fuente (mm)',
#  'Precip. anual promedio según SMN interpolado (mm/año)',
#  'Precipitación media anual tomada de geoportal IDESA',
#  'Taxonomía de suelo',
#  'Metodología/Comentarios',
#  'REGION',
#  'DOMINIO',
#  'UNIDAD FITOGEOGRÁFICA',
#  'Código de Unidad de Vegetación',
#  'Nombre fisionómico de Unidad de Vegetación',
#  'Nombre vulgar de Unidad de Vegetación',
#  'Excluidos del análisis']

# %%
#delete some columns not usefull for this data exploration and visualizations

df = df.drop(columns = [
 'DesvEst interanual (n)',
 'DesvEst interanual (kg/ha)',
 'DesvEst espacial (kg/ha)',
 'Edad (años)',
 'Fertilización  (S) (kg/ha.año)',
 'Fertilización  (K) (kg/ha.año)',
 'Pastoreo',
 'Clausura',
 'Precipitación (mm)',
 'Precipitación durante el año de medición (mm/estación de crecimiento)',
 'Precipitación promedio mencionada en la fuente (mm)',
 'Precip. anual promedio según SMN interpolado (mm/año)',
 'Código de Unidad de Vegetación',
 'Nombre fisionómico de Unidad de Vegetación',
 'Nombre vulgar de Unidad de Vegetación',
 ])

# %%
df
# Out:
#       ID Registro  ID fuente     LAT        LON  Celda  \
# 0             987      10110 -29.725 -65.425000  16785
# 1            4351      10508 -27.650 -58.766667  29049
# 2            4352      10508 -27.650 -58.766667  29049
# 3            4353      10508 -27.650 -58.766667  29049
# 4            4354      10508 -27.650 -58.766667  29049
# ...           ...        ...     ...        ...    ...
# 6377         1118      10137 -28.050 -64.250000  18635
# 6378         1120      10137 -28.050 -64.250000  18635
# 6379         1122      10137 -28.050 -64.250000  18635
# 6380         1124      10137 -28.050 -64.250000  18635
# 6381         1965      10213 -27.500 -59.166667  28304
#
#      Departamento, partido o comuna            Provincia Espontánea Recurso 1  \
# 0               Departamento La Paz            CATAMARCA         Sí    Estepa
# 1              Departamento Capital           CORRIENTES         No   Pastura
# 2              Departamento Capital           CORRIENTES         No   Pastura
# 3              Departamento Capital           CORRIENTES         No   Pastura
# 4              Departamento Capital           CORRIENTES         No   Pastura
# ...                             ...                  ...        ...       ...
# 6377           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6378           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6379           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6380           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6381      Departamento San Fernando                CHACO         No   Pastura
#
#      Recurso 2  ... Fertilización  (P) (kg/ha.año) Riego Cantidad riego (mm)  \
# 0     Pastizal  ...                              0    SD                   -
# 1      Pastura  ...                              0    No                   -
# 2      Pastura  ...                              0    No                   -
# 3      Pastura  ...                             55    No                   -
# 4      Pastura  ...                             55    No                   -
# ...        ...  ...                            ...   ...                 ...
# 6377  Pastizal  ...                              0    SD                   -
# 6378  Pastizal  ...                              0    SD                   -
# 6379  Pastizal  ...                              0    SD                   -
# 6380  Pastizal  ...                              0    SD                   -
# 6381   Pastura  ...                             60    No                   -
#
#      Precipitación media anual tomada de geoportal IDESA Taxonomía de suelo  \
# 0                                                   323                 NaN
# 1                                                  1340     Argiudol acuico
# 2                                                  1340     Argiudol acuico
# 3                                                  1340     Argiudol acuico
# 4                                                  1340     Argiudol acuico
# ...                                                 ...                 ...
# 6377                                                505                 NaN
# 6378                                                505                 NaN
# 6379                                                505                 NaN
# 6380                                                505                 NaN
# 6381                                               1310   Psamacualf típico
#
#                                 Metodología/Comentarios       REGION  \
# 0     Cortes de brotes nuevos de arbustos forrajeros...  Neotropical
# 1     Tres cortes en total. Altura remanente: 25% de...  Neotropical
# 2     Tres cortes en total. Altura remanente: 50% de...  Neotropical
# 3     Tres cortes en total. Altura remanente: 25% de...  Neotropical
# 4     Tres cortes en total. Altura remanente: 50% de...  Neotropical
# ...                                                 ...          ...
# 6377  Media loma - buena - rolado seguido de fuego p...  Neotropical
# 6378  Media loma - buena - rolado solo campo natural...  Neotropical
# 6379  Media loma, testigo, bosque abierto con fachin...  Neotropical
# 6380  Media loma, testigo, bosque abierto con fachin...  Neotropical
# 6381                                 fuente desconocida  Neotropical
#
#        DOMINIO              UNIDAD FITOGEOGRÁFICA Excluidos del análisis
# 0     Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 1     Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 2     Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 3     Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 4     Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# ...        ...                                ...                    ...
# 6377  Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 6378  Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 6379  Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 6380  Chaqueno  Provincia Fitogeografica Chaquena                    NaN
# 6381  Chaqueno  Provincia Fitogeografica Chaquena                    NaN
#
# [6382 rows x 33 columns]

# %%
df['Excluidos del análisis'].unique()

# I will drop the rows which have not 'nan' for this column since they correspond
# to rare anpp values
# Out:
# array([nan,
#        'No es adecuado sembrarla en reemplazo de los pastizales del chaco serrano (fuente)',
#        'Riego', 'Dosis de fertilización desconocida',
#        'Riego y dosis de fertilización desconocida',
#        'Outlier detectado por MAD', 'No se adaptó al sitio (fuente)',
#        'Presencia de valores de ppna = 0 en algunos tratamientos',
#        'Debilitamiento y mortandad de plantas producto de los frecuentes anegamientos, además del frío y la competencia por malezas (fuente)',
#        'Debido a una sequía la producción de forraje fue prácticamente nula (fuente)',
#        'Excluido por valor de ppna cercano a cero', 'Valor de ppna bajo'],
#       dtype=object)

# %%
# I want to exclude here the records (rows) that were excluded from the analysis I already did
# That means those that are not NaN for the "Excluidos del análisis" column

df['Excluidos del análisis'] = df['Excluidos del análisis'].fillna('OK')

# First fill de NaN cells with 'OK'
# Now I will drop the rows that are different from 'OK' for that column

for x in df.index:
    if df.loc[x, "Excluidos del análisis"] != 'OK':
        df.drop(x, inplace=True)
        
df
# Out:
#       ID Registro  ID fuente     LAT        LON  Celda  \
# 0             987      10110 -29.725 -65.425000  16785
# 1            4351      10508 -27.650 -58.766667  29049
# 2            4352      10508 -27.650 -58.766667  29049
# 3            4353      10508 -27.650 -58.766667  29049
# 4            4354      10508 -27.650 -58.766667  29049
# ...           ...        ...     ...        ...    ...
# 6377         1118      10137 -28.050 -64.250000  18635
# 6378         1120      10137 -28.050 -64.250000  18635
# 6379         1122      10137 -28.050 -64.250000  18635
# 6380         1124      10137 -28.050 -64.250000  18635
# 6381         1965      10213 -27.500 -59.166667  28304
#
#      Departamento, partido o comuna            Provincia Espontánea Recurso 1  \
# 0               Departamento La Paz            CATAMARCA         Sí    Estepa
# 1              Departamento Capital           CORRIENTES         No   Pastura
# 2              Departamento Capital           CORRIENTES         No   Pastura
# 3              Departamento Capital           CORRIENTES         No   Pastura
# 4              Departamento Capital           CORRIENTES         No   Pastura
# ...                             ...                  ...        ...       ...
# 6377           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6378           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6379           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6380           Departamento Capital  SANTIAGO DEL ESTERO         Sí    Estepa
# 6381      Departamento San Fernando                CHACO         No   Pastura
#
#      Recurso 2  ... Fertilización  (P) (kg/ha.año) Riego Cantidad riego (mm)  \
# 0     Pastizal  ...                              0    SD                   -
# 1      Pastura  ...                              0    No                   -
# 2      Pastura  ...                              0    No                   -
# 3      Pastura  ...                             55    No                   -
# 4      Pastura  ...                             55    No                   -
# ...        ...  ...                            ...   ...                 ...
# 6377  Pastizal  ...                              0    SD                   -
# 6378  Pastizal  ...                              0    SD                   -
# 6379  Pastizal  ...                              0    SD                   -
# 6380  Pastizal  ...                              0    SD                   -
# 6381   Pastura  ...                             60    No                   -
#
#      Precipitación media anual tomada de geoportal IDESA Taxonomía de suelo  \
# 0                                                   323                 NaN
# 1                                                  1340     Argiudol acuico
# 2                                                  1340     Argiudol acuico
# 3                                                  1340     Argiudol acuico
# 4                                                  1340     Argiudol acuico
# ...                                                 ...                 ...
# 6377                                                505                 NaN
# 6378                                                505                 NaN
# 6379                                                505                 NaN
# 6380                                                505                 NaN
# 6381                                               1310   Psamacualf típico
#
#                                 Metodología/Comentarios       REGION  \
# 0     Cortes de brotes nuevos de arbustos forrajeros...  Neotropical
# 1     Tres cortes en total. Altura remanente: 25% de...  Neotropical
# 2     Tres cortes en total. Altura remanente: 50% de...  Neotropical
# 3     Tres cortes en total. Altura remanente: 25% de...  Neotropical
# 4     Tres cortes en total. Altura remanente: 50% de...  Neotropical
# ...                                                 ...          ...
# 6377  Media loma - buena - rolado seguido de fuego p...  Neotropical
# 6378  Media loma - buena - rolado solo campo natural...  Neotropical
# 6379  Media loma, testigo, bosque abierto con fachin...  Neotropical
# 6380  Media loma, testigo, bosque abierto con fachin...  Neotropical
# 6381                                 fuente desconocida  Neotropical
#
#        DOMINIO              UNIDAD FITOGEOGRÁFICA Excluidos del análisis
# 0     Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 1     Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 2     Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 3     Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 4     Chaqueno  Provincia Fitogeografica Chaquena                     OK
# ...        ...                                ...                    ...
# 6377  Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 6378  Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 6379  Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 6380  Chaqueno  Provincia Fitogeografica Chaquena                     OK
# 6381  Chaqueno  Provincia Fitogeografica Chaquena                     OK
#
# [4951 rows x 33 columns]

# %%
# Run this again to check if the excluded rows where actually excluded

df['Excluidos del análisis'].unique()

# Great
# Out:
# array(['OK'], dtype=object)

# %%
df_by_resource_type = df.groupby('Recurso 2')['PPNA (kg/ha.año)'].mean().reset_index()

# The reset.index() function converts 
# right away the group by in a new dataframe

df_by_resource_type
# Out:
#          Recurso 2  PPNA (kg/ha.año)
# 0         Pastizal       2221.990584
# 1          Pastura       7877.940606
# 2  Verdeo Invierno       5673.404518
# 3    Verdeo Verano      14513.150000
# 4             otro       5535.666667

# %%
# I should rename the headers in English

df_by_resource_type = df_by_resource_type.rename(columns={
    'Recurso 2': 'Resource', 
    'PPNA (kg/ha.año)': 'mean ANPP(kg/ha.year)'})

df_by_resource_type
# Out:
#           Resource  mean ANPP(kg/ha.year)
# 0         Pastizal            2221.990584
# 1          Pastura            7877.940606
# 2  Verdeo Invierno            5673.404518
# 3    Verdeo Verano           14513.150000
# 4             otro            5535.666667

# %%
df_by_resource_type.drop(df_by_resource_type.tail(1).index,inplace=True)

# df.drop(df.tail(n).index,inplace=True) 
# drop last n rows

# Since n = 1 in the funciton, only the last row was dropped. The 4th row
# If n = 2, the last 2 rows would had been dropped. the 3th and 4th rows

# %%
df_by_resource_type
# Out:
#           Resource  mean ANPP(kg/ha.year)
# 0         Pastizal            2221.990584
# 1          Pastura            7877.940606
# 2  Verdeo Invierno            5673.404518
# 3    Verdeo Verano           14513.150000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab


fig_df_by_resource_type = df_by_resource_type.set_index('Resource')

# So the names for each colmun along the x axis are 
#the different resources instead on numbers

fig_df_by_resource_type.plot(kind = 'bar', title = 'Mean ANPP by resource',
                        xlabel = 'Resource', 
                        ylabel = 'Mean ANPP (kg/ha.year-1)',
                        rot=0,
                        figsize = (10,4),
                        legend = False)


#Font size setting for plots
 
SMALL_SIZE = 5
MEDIUM_SIZE = 10
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# I would like to see how ANPP differs between fitogeographic regions instead of resource type

df_by_region = df.groupby('UNIDAD FITOGEOGRÁFICA')['PPNA (kg/ha.año)'].mean().reset_index()

# %%
# I should rename the headers in English

df_by_region = df_by_region.rename(columns={
    'UNIDAD FITOGEOGRÁFICA': 'Region', 
    'PPNA (kg/ha.año)': 'mean ANPP (kg/ha.year)'})

# %%
# Not all regions are well represented, some of them have just a few records, 
#such as the Ecotono Monte-Patagonia and the Punena region

df.groupby('UNIDAD FITOGEOGRÁFICA')['PPNA (kg/ha.año)'].count()
# Out:
# UNIDAD FITOGEOGRÁFICA
# Ecotono Fitogeografico Monte-Patagonia       4
# Provincia Fitogeografica Altoandina         26
# Provincia Fitogeografica Chaquena          679
# Provincia Fitogeografica Pampeana         2377
# Provincia Fitogeografica Paranaense         77
# Provincia Fitogeografica Patagonica        267
# Provincia Fitogeografica Prepunena           1
# Provincia Fitogeografica Punena             17
# Provincia Fitogeografica Subantartica       15
# Provincia Fitogeografica de las Yungas      16
# Provincia Fitogeografica del Espinal      1239
# Provincia Fitogeografica del Monte         233
# Name: PPNA (kg/ha.año), dtype: int64

# %%
# Since some regions have just a few records I will exclude them of the next plot

poor_data_regions = [0, 1, 4, 6, 7, 8, 9]

df_by_region.drop(poor_data_regions, axis=0, inplace=True)

# %%
df_by_region = df_by_region.reset_index(drop=True)

df_by_region
# Out:
#                                  Region  mean ANPP (kg/ha.year)
# 0     Provincia Fitogeografica Chaquena             5128.869323
# 1     Provincia Fitogeografica Pampeana             7858.717968
# 2   Provincia Fitogeografica Patagonica             1491.318124
# 3  Provincia Fitogeografica del Espinal             8520.734323
# 4    Provincia Fitogeografica del Monte             3122.742876

# %%
df_by_region['Region'] = df_by_region['Region'].str.replace('Provincia Fitogeografica ','')

df_by_region
# Out:
#         Region  mean ANPP (kg/ha.year)
# 0     Chaquena             5128.869323
# 1     Pampeana             7858.717968
# 2   Patagonica             1491.318124
# 3  del Espinal             8520.734323
# 4    del Monte             3122.742876

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab


fig_df_by_region = df_by_region.set_index('Region')

# So the names for each colmun along the x axis are 
# the different regions instead on numbers

fig_df_by_region.plot(kind = 'bar', title = 'Mean ANPP by region',
                        xlabel = 'Region', 
                        ylabel = 'Mean ANPP (kg/ha.year-1)',
                        rot=0,
                        figsize = (10,4),
                        legend = False,
                        color = "green")


#Font size setting for plots
 
SMALL_SIZE = 5
MEDIUM_SIZE = 10
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# How does precipitation changes mean ANPP

df.plot.scatter(x = 'Precipitación media anual tomada de geoportal IDESA',
                y = 'PPNA (kg/ha.año)',
                c = 'black')
# Out:
# <Axes: xlabel='Precipitación media anual tomada de geoportal IDESA', ylabel='PPNA (kg/ha.año)'>
